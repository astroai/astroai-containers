# %% [markdown]
# # AstroAI + Ray
#
# Use the **stock Ray Dashboard** from a CANFAR **contributed `ray-manager`** session.
#
# 1. Once: `canfar login` (from webterm/vscode)
# 2. Laptop/portal: launch `ray-manager` (or `scripts/ray-launch.sh`)
# 3. `canfar ps` → open **connectURL** → create workers → open `…/dashboard/`
# 4. Submit with Dashboard Jobs, or `RayExecutor()` on the manager (`ASTROAI_RAY_JOBS_ADDRESS` is set — no host guessing)
# 5. MNIST sample: see `astroai-workload` `examples/mnist_cnn/`

# %%
# On the ray-manager session after workers are attached:
# from astroai_workload import RayExecutor, ResourceRequest, RunSpec
# RayExecutor().submit(RunSpec(run_id="demo", command=("python", "-c", "print('ok')"),
#                              resources=ResourceRequest(cpus=1, memory="1GiB")))
print("See docs/RAY.md and astroai-workload examples/mnist_cnn/")
